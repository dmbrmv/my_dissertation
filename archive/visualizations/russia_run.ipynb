# %%
import pickle
from pprint import pprint
print = pprint
import tqdm.notebook as tqdm
import glob

from pathlib import Path
from typing import List, Dict, Union, Tuple
import random
from functools import reduce

import torch
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd

import neuralhydrology
from neuralhydrology.datasetzoo.basedataset import BaseDataset
from neuralhydrology.utils.config import Config
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run

random.seed(42)

# %% [markdown]
# ### Setup needed attributes

# %%
def df_from_list(df_list: list, merge_col='date') -> pd.DataFrame:
    """Function merge DataFrames from list to the single frame

    Args:
        df_list (list): List of dataframes
        merge_col (str, optional): column on which merge will be perfomed.
                                   Defaults to 'date'.

    Returns:
        pd.DataFrame: Merged dataframe
    """
    return reduce(lambda left, right: pd.merge(left, right, on=merge_col),
                  df_list)


attribute_list = [pd.read_pickle(my_file).reset_index() for my_file
                  in glob.glob('./attributes/*.pkl')]
attribute_list = df_from_list(df_list=attribute_list,
                              merge_col='gauge_id')
attribute_list = attribute_list.set_index('gauge_id', drop=True)
attribute_list.to_csv('./attributes/static_data.csv')

# %% [markdown]
# ### Prepare AIS GMVO streamflow

# %%
# select only valiable data for OpenForecast
ais_stream_OF = pd.read_csv('./streamflow/ais_layers.csv')
ais_stream_OF = ais_stream_OF.dropna(axis=1)
# slice every available observation by it
ais_stream = pd.read_pickle('./streamflow/water_consumption.pkl')
ais_stream = ais_stream.set_index('Date')
ais_stream = ais_stream.dropna(axis=1)
ais_stream.columns = map(str, ais_stream.columns)
ais_stream.index = ais_stream.index.rename('date')
ais_stream = ais_stream[ais_stream_OF.columns]

# %% [markdown]
# ### Select OpenForecast basins
# probably its just AIS GMVO data w/o missing values

# %%
gauges = list(ais_stream.columns)
with open('./openf_basins.txt', 'w') as the_file:
    for gauge_name in gauges:
        the_file.write(f'{int(gauge_name)}\n')

# %% [markdown]
# ### Split test, val, train

# %%
random.shuffle(gauges)
gauge_size = len(gauges)

train_gauges = gauges[:int(len(gauges) * 0.8)]
with open('./basins_train.txt', 'w') as the_file:
    for gauge_name in train_gauges:
        the_file.write(f'{gauge_name}\n')

val_gauges = gauges[int(gauge_size * 0.8):int(gauge_size * 0.8) + int(gauge_size * 0.1)]
with open('./basins_val.txt', 'w') as the_file:
    for gauge_name in val_gauges:
        the_file.write(f'{gauge_name}\n')

test_gauges = gauges[int(gauge_size * 0.8) + int(gauge_size * 0.1):]
with open('./basins_test.txt', 'w') as the_file:
    for gauge_name in test_gauges:
        the_file.write(f'{gauge_name}\n')

# %% [markdown]
# ### Merge meteo and streamflow into single file

# %%
meteo_pathes = glob.glob('./forcings/*')


def read_multi_meteo(meteo_pathes: list, gauge_id: str) -> pd.DataFrame:
    meteo_list = [pd.read_pickle(f'{path}/{gauge_id}.pkl')
                  for path in meteo_pathes]
    meteo_list = df_from_list(meteo_list)
    meteo_list = meteo_list.set_index('date')

    meteo_list = meteo_list.rename(columns={'t2m_x': 'temp_max',
                                            't2m_y': 'temp_min',
                                            'msdrswrf': 'srad_avg',
                                            'tp': 'precip'})
    # to celsius
    meteo_list[['temp_min', 'temp_max']] = meteo_list[[
        'temp_min', 'temp_max', ]].apply(lambda x: x-273.15)
    # # to mm
    meteo_list[['precip']] = meteo_list[['precip']] * 1e2

    return meteo_list

# %%
path_to_store = Path('./time_series/')
path_to_store.mkdir(exist_ok=True, parents=True)
physio_data = pd.read_pickle('./attributes/physio.pkl')

for gauge in tqdm.tqdm(gauges):
    area = physio_data.loc[gauge, 'ws_area']

    meteo_obs = read_multi_meteo(meteo_pathes,
                                 gauge)
    res_file = pd.DataFrame()
    res_file['QObs'] = 10**3 * \
        (ais_stream[gauge] * 86400) / (area * 10**6)
    res_file.index = pd.to_datetime(res_file.index)
    res_file = res_file.join(meteo_obs)
    res_file = res_file.to_xarray()

    res_file.to_netcdf(f'{path_to_store}/{gauge}.nc')
# Out:
# A Jupyter Widget

# %% [markdown]
# ### Try to run ...

# %%
if torch.cuda.is_available():
    start_run(config_file=Path("./config.yml"))
# Out:
# 2023-02-21 17:32:34,126: Logging to runs/era5_whole_wSNW_2102_173234/output.log initialized.
# 2023-02-21 17:32:34,126: ### Folder structure created at runs/era5_whole_wSNW_2102_173234
# 2023-02-21 17:32:34,127: ### Run configurations for era5_whole_wSNW
# 2023-02-21 17:32:34,127: experiment_name: era5_whole_wSNW
# 2023-02-21 17:32:34,128: run_dir: runs/era5_whole_wSNW_2102_173234
# 2023-02-21 17:32:34,128: train_basin_file: openf_basins.txt
# 2023-02-21 17:32:34,128: validation_basin_file: openf_basins.txt
# 2023-02-21 17:32:34,129: test_basin_file: openf_basins.txt
# 2023-02-21 17:32:34,129: train_start_date: 2008-01-01 00:00:00
# 2023-02-21 17:32:34,129: train_end_date: 2015-12-31 00:00:00
# 2023-02-21 17:32:34,130: validation_start_date: 2016-01-01 00:00:00
# 2023-02-21 17:32:34,130: validation_end_date: 2017-12-31 00:00:00
# 2023-02-21 17:32:34,130: test_start_date: 2018-01-01 00:00:00
# 2023-02-21 17:32:34,131: test_end_date: 2019-12-31 00:00:00
# 2023-02-21 17:32:34,131: per_basin_train_periods_file: None
# 2023-02-21 17:32:34,132: per_basin_validation_periods_file: None
# 2023-02-21 17:32:34,132: per_basin_test_periods_file: None
# 2023-02-21 17:32:34,132: seed: 42
# 2023-02-21 17:32:34,133: device: cuda:0
# 2023-02-21 17:32:34,133: validate_every: 3
# 2023-02-21 17:32:34,133: validate_n_random_basins: 527
# 2023-02-21 17:32:34,134: cache_validation_data: True
# 2023-02-21 17:32:34,134: metrics: ['NSE', 'KGE']
# 2023-02-21 17:32:34,134: model: cudalstm
# 2023-02-21 17:32:34,135: checkpoint_path: None
# 2023-02-21 17:32:34,135: head: regression
# 2023-02-21 17:32:34,135: output_activation: linear
# 2023-02-21 17:32:34,136: hidden_size: 512
# 2023-02-21 17:32:34,136: initial_forget_bias: 6
# 2023-02-21 17:32:34,136: output_dropout: 0.42
# 2023-02-21 17:32:34,137: optimizer: Adam
# 2023-02-21 17:32:34,137: loss: NSE
# 2023-02-21 17:32:34,137: regularization: None
# 2023-02-21 17:32:34,138: learning_rate: {0: 0.001, 10: 0.0005, 20: 0.0001}
# 2023-02-21 17:32:34,138: batch_size: 256
# 2023-02-21 17:32:34,138: epochs: 60
# 2023-02-21 17:32:34,139: target_noise_std: None
# 2023-02-21 17:32:34,139: clip_gradient_norm: 1
# 2023-02-21 17:32:34,140: predict_last_n: 1
# 2023-02-21 17:32:34,140: seq_length: 365
# 2023-02-21 17:32:34,140: num_workers: 8
# 2023-02-21 17:32:34,141: log_interval: 5
# 2023-02-21 17:32:34,141: log_tensorboard: True
# 2023-02-21 17:32:34,141: log_n_figures: None
# 2023-02-21 17:32:34,142: save_weights_every: 1
# 2023-02-21 17:32:34,142: save_validation_results: True
# 2023-02-21 17:32:34,142: dataset: generic
# 2023-02-21 17:32:34,143: data_dir: .
# 2023-02-21 17:32:34,143: save_train_data: True
# 2023-02-21 17:32:34,143: train_data_file: None
# 2023-02-21 17:32:34,143: forcings: None
# 2023-02-21 17:32:34,144: dynamic_inputs: ['temp_max', 'temp_min', 'precip']
# 2023-02-21 17:32:34,144: target_variables: ['QObs']
# 2023-02-21 17:32:34,144: static_attributes: ['for_pc_sse', 'crp_pc_sse', 'inu_pc_ult', 'ire_pc_sse', 'lka_pc_use', 'gwt_cm_sav', 'prm_pc_sse', 'pst_pc_sse', 'lkv_mc_usu', 'rev_mc_usu', 'sgr_dk_sav', 'slp_dg_sav', 'cly_pc_sav', 'slt_pc_sav', 'snd_pc_sav', 'kar_pc_sse', 'urb_pc_sse', 'ws_area', 'ele_mt_sav', 'snw_pc_s01', 'snw_pc_s02', 'snw_pc_s03', 'snw_pc_s04', 'snw_pc_s05', 'snw_pc_s06', 'snw_pc_s07', 'snw_pc_s08', 'snw_pc_s09', 'snw_pc_s10', 'snw_pc_s11', 'snw_pc_s12']
# 2023-02-21 17:32:34,145: additional_feature_files: None
# 2023-02-21 17:32:34,145: evolving_attributes: None
# 2023-02-21 17:32:34,145: use_basin_id_encoding: False
# 2023-02-21 17:32:34,146: number_of_basins: 527
# 2023-02-21 17:32:34,146: train_dir: runs/era5_whole_wSNW_2102_173234/train_data
# 2023-02-21 17:32:34,146: img_log_dir: runs/era5_whole_wSNW_2102_173234/img_log
# 2023-02-21 17:32:34,147: ### Device cuda:0 will be used for training
# 2023-02-21 17:32:34,247: Loading basin data into xarray data set.
# 100%|██████████| 527/527 [00:05<00:00, 97.33it/s]
# 2023-02-21 17:32:40,180: Calculating target variable stds per basin
#  58%|█████▊    | 305/527 [00:00<00:00, 1539.65it/s]
# /opt/conda/lib/python3.9/site-packages/neuralhydrology/datasetzoo/basedataset.py:421: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1666643016022/work/torch/csrc/utils/tensor_new.cpp:230.)
#   per_basin_target_stds = torch.tensor([np.nanstd(obs, axis=1)], dtype=torch.float32)
# 100%|██████████| 527/527 [00:00<00:00, 1535.87it/s]
# 2023-02-21 17:32:40,577: Create lookup table and convert to pytorch tensor
# 100%|██████████| 527/527 [00:07<00:00, 74.65it/s]
# # Epoch 1: 100%|██████████| 5266/5266 [04:47<00:00, 18.33it/s, Loss: 0.0000]
# 2023-02-21 17:37:35,139: Epoch 1 average loss: 0.0019190718485564923
# # Epoch 2: 100%|██████████| 5266/5266 [04:46<00:00, 18.37it/s, Loss: 0.0000]
# 2023-02-21 17:42:21,803: Epoch 2 average loss: 0.00035836096770039974
# # Epoch 3: 100%|██████████| 5266/5266 [04:48<00:00, 18.27it/s, Loss: 0.0000]
# 2023-02-21 17:47:10,002: Epoch 3 average loss: 1.9151045735526213e-05
# # Validation: 100%|██████████| 527/527 [00:56<00:00,  9.40it/s]
# 2023-02-21 17:48:06,146: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch003/validation_results.p
# 2023-02-21 17:48:06,158: Epoch 3 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.15761, KGE: 0.14779
# # Epoch 4: 100%|██████████| 5266/5266 [04:49<00:00, 18.18it/s, Loss: 0.0000]
# 2023-02-21 17:52:55,780: Epoch 4 average loss: 1.3244581233890394e-05
# # Epoch 5: 100%|██████████| 5266/5266 [04:49<00:00, 18.17it/s, Loss: 0.0000]
# 2023-02-21 17:57:45,605: Epoch 5 average loss: 8.374005310178578e-06
# # Epoch 6: 100%|██████████| 5266/5266 [04:49<00:00, 18.17it/s, Loss: 0.0000]
# 2023-02-21 18:02:35,423: Epoch 6 average loss: 7.1215103921771475e-06
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.54it/s]
# 2023-02-21 18:03:14,421: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch006/validation_results.p
# 2023-02-21 18:03:14,425: Epoch 6 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.42167, KGE: 0.43888
# # Epoch 7: 100%|██████████| 5266/5266 [04:49<00:00, 18.17it/s, Loss: 0.0000]
# 2023-02-21 18:08:04,246: Epoch 7 average loss: 6.041006198701709e-06
# # Epoch 8: 100%|██████████| 5266/5266 [04:49<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 18:12:54,177: Epoch 8 average loss: 5.545634042878138e-06
# # Epoch 9: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 18:17:44,371: Epoch 9 average loss: 8.125910353709954e-05
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.57it/s]
# 2023-02-21 18:18:23,295: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch009/validation_results.p
# 2023-02-21 18:18:23,299: Epoch 9 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.35000, KGE: 0.38610
# 2023-02-21 18:18:23,300: Setting learning rate to 0.0005
# # Epoch 10: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 18:23:13,553: Epoch 10 average loss: 6.8584829328950445e-06
# # Epoch 11: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 18:28:03,920: Epoch 11 average loss: 4.99584186585489e-06
# # Epoch 12: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 18:32:54,014: Epoch 12 average loss: 4.5375815680430475e-06
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.54it/s]
# 2023-02-21 18:33:33,027: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch012/validation_results.p
# 2023-02-21 18:33:33,031: Epoch 12 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.64464, KGE: 0.62559
# # Epoch 13: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 18:38:23,279: Epoch 13 average loss: 4.432603242522196e-06
# # Epoch 14: 100%|██████████| 5266/5266 [04:49<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 18:43:13,280: Epoch 14 average loss: 3.6499961318591514e-05
# # Epoch 15: 100%|██████████| 5266/5266 [04:50<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 18:48:03,303: Epoch 15 average loss: 5.596114861134991e-06
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.57it/s]
# 2023-02-21 18:48:42,222: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch015/validation_results.p
# 2023-02-21 18:48:42,226: Epoch 15 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.51847, KGE: 0.49811
# # Epoch 16: 100%|██████████| 5266/5266 [04:50<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 18:53:32,264: Epoch 16 average loss: 4.270103462025205e-06
# # Epoch 17: 100%|██████████| 5266/5266 [04:49<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 18:58:22,203: Epoch 17 average loss: 4.243802047826253e-06
# # Epoch 18: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 19:03:12,356: Epoch 18 average loss: 4.159690743248409e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.39it/s]
# 2023-02-21 19:03:51,788: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch018/validation_results.p
# 2023-02-21 19:03:51,791: Epoch 18 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.63802, KGE: 0.62774
# # Epoch 19: 100%|██████████| 5266/5266 [04:50<00:00, 18.10it/s, Loss: 0.0000]
# 2023-02-21 19:08:42,710: Epoch 19 average loss: 4.06379352167807e-06
# 2023-02-21 19:08:42,723: Setting learning rate to 0.0001
# # Epoch 20: 100%|██████████| 5266/5266 [04:50<00:00, 18.10it/s, Loss: 0.0000]
# 2023-02-21 19:13:33,658: Epoch 20 average loss: 3.4393126316327014e-06
# # Epoch 21: 100%|██████████| 5266/5266 [04:50<00:00, 18.11it/s, Loss: 0.0000]
# 2023-02-21 19:18:24,440: Epoch 21 average loss: 3.3723087603493646e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.47it/s]
# 2023-02-21 19:19:03,653: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch021/validation_results.p
# 2023-02-21 19:19:03,657: Epoch 21 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.65823, KGE: 0.66336
# # Epoch 22: 100%|██████████| 5266/5266 [04:50<00:00, 18.12it/s, Loss: 0.0000]
# 2023-02-21 19:23:54,290: Epoch 22 average loss: 3.344071059283399e-06
# # Epoch 23: 100%|██████████| 5266/5266 [04:50<00:00, 18.13it/s, Loss: 0.0000]
# 2023-02-21 19:28:44,747: Epoch 23 average loss: 3.3042094488115063e-06
# # Epoch 24: 100%|██████████| 5266/5266 [04:50<00:00, 18.13it/s, Loss: 0.0000]
# 2023-02-21 19:33:35,259: Epoch 24 average loss: 3.286131619169176e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.29it/s]
# 2023-02-21 19:34:15,017: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch024/validation_results.p
# 2023-02-21 19:34:15,021: Epoch 24 average validation loss: 0.00000 -- Median validation metrics: NSE: 0.67276, KGE: 0.66489
# # Epoch 25: 100%|██████████| 5266/5266 [04:50<00:00, 18.12it/s, Loss: 0.0000]
# 2023-02-21 19:39:05,712: Epoch 25 average loss: 3.2608035254186424e-06
# # Epoch 26: 100%|██████████| 5266/5266 [04:50<00:00, 18.13it/s, Loss: 0.0000]
# 2023-02-21 19:43:56,207: Epoch 26 average loss: 3.2278461649821766e-06
# # Epoch 27: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 19:48:46,395: Epoch 27 average loss: 3.2014514156057677e-06
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.63it/s]
# 2023-02-21 19:49:25,141: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch027/validation_results.p
# 2023-02-21 19:49:25,145: Epoch 27 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.64017, KGE: 0.61725
# # Epoch 28: 100%|██████████| 5266/5266 [04:50<00:00, 18.10it/s, Loss: 0.0000]
# 2023-02-21 19:54:16,131: Epoch 28 average loss: 3.1918569611898564e-06
# # Epoch 29: 100%|██████████| 5266/5266 [04:50<00:00, 18.10it/s, Loss: 0.0000]
# 2023-02-21 19:59:07,091: Epoch 29 average loss: 3.14899665592673e-06
# # Epoch 30: 100%|██████████| 5266/5266 [04:50<00:00, 18.11it/s, Loss: 0.0000]
# 2023-02-21 20:03:57,958: Epoch 30 average loss: 3.1480077805023435e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.42it/s]
# 2023-02-21 20:04:37,301: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch030/validation_results.p
# 2023-02-21 20:04:37,305: Epoch 30 average validation loss: 0.00000 -- Median validation metrics: NSE: 0.66907, KGE: 0.68615
# # Epoch 31: 100%|██████████| 5266/5266 [04:50<00:00, 18.10it/s, Loss: 0.0000]
# 2023-02-21 20:09:28,235: Epoch 31 average loss: 3.1386640065674894e-06
# # Epoch 32: 100%|██████████| 5266/5266 [04:50<00:00, 18.11it/s, Loss: 0.0000]
# 2023-02-21 20:14:18,977: Epoch 32 average loss: 3.096641219057871e-06
# # Epoch 33: 100%|██████████| 5266/5266 [04:50<00:00, 18.12it/s, Loss: 0.0000]
# 2023-02-21 20:19:09,570: Epoch 33 average loss: 3.0916681238441006e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.50it/s]
# 2023-02-21 20:19:48,672: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch033/validation_results.p
# 2023-02-21 20:19:48,676: Epoch 33 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.64836, KGE: 0.66075
# # Epoch 34: 100%|██████████| 5266/5266 [04:50<00:00, 18.12it/s, Loss: 0.0000]
# 2023-02-21 20:24:39,301: Epoch 34 average loss: 3.0682639579642788e-06
# # Epoch 35: 100%|██████████| 5266/5266 [04:50<00:00, 18.13it/s, Loss: 0.0000]
# 2023-02-21 20:29:29,829: Epoch 35 average loss: 3.038122815952751e-06
# # Epoch 36: 100%|██████████| 5266/5266 [04:50<00:00, 18.13it/s, Loss: 0.0000]
# 2023-02-21 20:34:20,355: Epoch 36 average loss: 3.020493295577414e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.49it/s]
# 2023-02-21 20:34:59,487: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch036/validation_results.p
# 2023-02-21 20:34:59,491: Epoch 36 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.65145, KGE: 0.66550
# # Epoch 37: 100%|██████████| 5266/5266 [04:50<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 20:39:49,544: Epoch 37 average loss: 3.0095592240967175e-06
# # Epoch 38: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 20:44:39,838: Epoch 38 average loss: 2.9928030963215525e-06
# # Epoch 39: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 20:49:30,127: Epoch 39 average loss: 3.997835492402319e-06
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.55it/s]
# 2023-02-21 20:50:09,105: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch039/validation_results.p
# 2023-02-21 20:50:09,109: Epoch 39 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.66632, KGE: 0.68198
# # Epoch 40: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 20:54:59,341: Epoch 40 average loss: 3.1198771746071905e-06
# # Epoch 41: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 20:59:49,618: Epoch 41 average loss: 5.308311771686624e-06
# # Epoch 42: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 21:04:39,727: Epoch 42 average loss: 4.80614359507106e-06
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.57it/s]
# 2023-02-21 21:05:18,636: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch042/validation_results.p
# 2023-02-21 21:05:18,640: Epoch 42 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.61871, KGE: 0.65559
# # Epoch 43: 100%|██████████| 5266/5266 [04:49<00:00, 18.17it/s, Loss: 0.0000]
# 2023-02-21 21:10:08,504: Epoch 43 average loss: 4.887045192350291e-06
# # Epoch 44: 100%|██████████| 5266/5266 [04:50<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 21:14:58,566: Epoch 44 average loss: 3.967418509734487e-06
# # Epoch 45: 100%|██████████| 5266/5266 [04:49<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 21:19:48,567: Epoch 45 average loss: 3.2612478216546853e-06
# # Validation: 100%|██████████| 527/527 [00:38<00:00, 13.61it/s]
# 2023-02-21 21:20:27,860: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch045/validation_results.p
# 2023-02-21 21:20:27,865: Epoch 45 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.66553, KGE: 0.68201
# # Epoch 46: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 21:25:17,964: Epoch 46 average loss: 3.0340074513365043e-06
# # Epoch 47: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 21:30:08,147: Epoch 47 average loss: 2.97125660098223e-06
# # Epoch 48: 100%|██████████| 5266/5266 [04:50<00:00, 18.14it/s, Loss: 0.0000]
# 2023-02-21 21:34:58,458: Epoch 48 average loss: 2.943344269346612e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.50it/s]
# 2023-02-21 21:35:37,563: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch048/validation_results.p
# 2023-02-21 21:35:37,567: Epoch 48 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.66192, KGE: 0.68976
# # Epoch 49: 100%|██████████| 5266/5266 [04:50<00:00, 18.13it/s, Loss: 0.0000]
# 2023-02-21 21:40:27,961: Epoch 49 average loss: 2.9247092128768304e-06
# # Epoch 50: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 21:45:18,054: Epoch 50 average loss: 2.8977715785179785e-06
# # Epoch 51: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 21:50:08,139: Epoch 51 average loss: 2.8781759760517384e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.45it/s]
# 2023-02-21 21:50:47,433: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch051/validation_results.p
# 2023-02-21 21:50:47,440: Epoch 51 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.67436, KGE: 0.69873
# # Epoch 52: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 21:55:37,615: Epoch 52 average loss: 2.853618302141379e-06
# # Epoch 53: 100%|██████████| 5266/5266 [04:50<00:00, 18.15it/s, Loss: 0.0000]
# 2023-02-21 22:00:27,699: Epoch 53 average loss: 2.832465748134664e-06
# # Epoch 54: 100%|██████████| 5266/5266 [04:50<00:00, 18.16it/s, Loss: 0.0000]
# 2023-02-21 22:05:17,764: Epoch 54 average loss: 2.827567360134344e-06
# # Validation: 100%|██████████| 527/527 [00:39<00:00, 13.50it/s]
# 2023-02-21 22:05:56,875: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch054/validation_results.p
# 2023-02-21 22:05:56,879: Epoch 54 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.67172, KGE: 0.68165
# # Epoch 55: 100%|██████████| 5266/5266 [04:52<00:00, 18.02it/s, Loss: 0.0000]
# 2023-02-21 22:10:49,074: Epoch 55 average loss: 2.8022167790798134e-06
# # Epoch 56: 100%|██████████| 5266/5266 [04:58<00:00, 17.61it/s, Loss: 0.0000]
# 2023-02-21 22:15:48,074: Epoch 56 average loss: 2.789424481858389e-06
# # Epoch 57: 100%|██████████| 5266/5266 [05:14<00:00, 16.76it/s, Loss: 0.0000]
# 2023-02-21 22:21:02,348: Epoch 57 average loss: 2.7663031744439172e-06
# # Validation: 100%|██████████| 527/527 [00:42<00:00, 12.37it/s]
# 2023-02-21 22:21:45,035: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch057/validation_results.p
# 2023-02-21 22:21:45,040: Epoch 57 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.63641, KGE: 0.68234
# # Epoch 58: 100%|██████████| 5266/5266 [05:15<00:00, 16.68it/s, Loss: 0.0000]
# 2023-02-21 22:27:00,684: Epoch 58 average loss: 2.7568571426527473e-06
# # Epoch 59: 100%|██████████| 5266/5266 [05:13<00:00, 16.81it/s, Loss: 0.0000]
# 2023-02-21 22:32:13,890: Epoch 59 average loss: 2.747378600268803e-06
# # Epoch 60: 100%|██████████| 5266/5266 [05:16<00:00, 16.61it/s, Loss: 0.0000]
# 2023-02-21 22:37:30,894: Epoch 60 average loss: 2.7225800256548296e-06
# # Validation: 100%|██████████| 527/527 [00:42<00:00, 12.33it/s]
# 2023-02-21 22:38:13,728: Stored results at runs/era5_whole_wSNW_2102_173234/validation/model_epoch060/validation_results.p
# 2023-02-21 22:38:13,732: Epoch 60 average validation loss: 0.00001 -- Median validation metrics: NSE: 0.65693, KGE: 0.68963

# %% [markdown]
# ### А вот и позор 😳

# %%
import matplotlib.pyplot as plt
run_dir = Path("./runs/era5_test54_ealstm_2002_052240")
eval_run(run_dir=run_dir, period="test")
# Out:
# 2023-02-20 11:32:53,687: Using the model weights from runs/era5_test54_ealstm_2002_052240/model_epoch042.pt
# # Evaluation: 100%|██████████| 54/54 [00:43<00:00,  1.24it/s]
# 2023-02-20 11:33:37,418: Stored results at runs/era5_test54_ealstm_2002_052240/test/model_epoch042/test_results.p

# %%
run_dir = Path("./runs/era5_test54_ealstm_2002_052240")

with open(run_dir / "test" / "model_epoch042" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)
counter = 0
for gauge in results.keys():
    if counter == 6:
        break
    qobs = results[gauge]['1D']['xr']['QObs_obs']
    qsim = results[gauge]['1D']['xr']['QObs_sim']

    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(qobs['date'], qobs)
    ax.plot(qsim['date'], qsim)
    ax.set_ylabel("Discharge (mm/d)")
    ax.set_title(f"""Test period - NSE {results[gauge]['1D']['NSE']:.3f}
For gauge - {gauge}
With area of {physio_data.loc[gauge]['ws_area']:.2f}""")
    counter += 1

# %%
import matplotlib.pyplot as plt
run_dir = Path("./runs/era5_test54_wstatic_1902_182418")
physio_data = pd.read_pickle('./attributes/physio.pkl')

# %%
with open(run_dir / "test" / "model_epoch042" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)
counter = 0
for gauge in results.keys():
    if counter == 6:
        break
    qobs = results[gauge]['1D']['xr']['QObs_obs']
    qsim = results[gauge]['1D']['xr']['QObs_sim']

    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(qobs['date'], qobs)
    ax.plot(qsim['date'], qsim)
    ax.set_ylabel("Discharge (mm/d)")
    ax.set_title(f"""Test period - NSE {results[gauge]['1D']['NSE']:.3f}
For gauge - {gauge}
With area of {physio_data.loc[gauge]['ws_area']:.2f}""")
    counter += 1

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path

run_dir = Path("./runs/everything_LSTM")

with open(run_dir / "test" / "model_epoch030" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)
counter = 0

# %%
qobs = results['9337']['1D']['xr']['QObs_obs']
qsim = results['9337']['1D']['xr']['QObs_sim']

fig, ax = plt.subplots(figsize=(16, 10))
ax.plot(qobs['date'], qobs)
ax.plot(qsim['date'], qsim)
ax.set_ylabel("Discharge (mm/d)")
ax.set_title(f"Test period - NSE {results['9337']['1D']['NSE']:.3f}");

# %%
for gauge in results.keys():
    if counter == 6:
        break
    qobs = results[gauge]['1D']['xr']['QObs_obs']
    qsim = results[gauge]['1D']['xr']['QObs_sim']

    fig, ax = plt.subplots(figsize=(16, 10))
    ax.plot(qobs['date'], qobs)
    ax.plot(qsim['date'], qsim)
    ax.set_ylabel("Discharge (mm/d)")
    ax.set_title(f"Test period - NSE {results[gauge]['1D']['NSE']:.3f}")
    counter += 1
